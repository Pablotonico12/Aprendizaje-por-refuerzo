# %%
import pandas as pd

# %% [markdown]
# Utilizando los datos recogidos en el fichero de datos abiertos de PDI de la UAM correspondiente al año 2020, se realiza, para cada campo del fichero exceptuando aquellos cuyo nombre empieza por "cod_" "lat_" y "lon_", lo siguiente:
# * Inferir el valor más probable de cada campo para el caso del profesor Ortigosa
# * Calcular el nivel de certeza (%) de que cada valor inferido corresponda realmente al profesor Ortigosa
# * Una breve descripción del proceso de inferencia utilizado en cada caso
#
#
# Para ello, se asegura que:
# * El profesor Ortigosa estaba en 2020 en la UAM (=aparece en el fichero)
# * El profesor Ortigosa era de género masculino en 2020
# * El profesor Ortigosa pertenecía al Departamento de Ingeniería Informática en 2020
#
#
# Las fuentes externas utilizadas para inferir información sobre Ortigosa son:
# 1. [https://portalcientifico.uam.es/ipublic/agent-personal/profile/iMarinaID/04-261195](https://portalcientifico.uam.es/ipublic/agent-personal/profile/iMarinaID/04-261195)
# 2. [https://es.linkedin.com/in/alvaroortigosa](https://es.linkedin.com/in/alvaroortigosa)
# 3. [https://ieeexplore.ieee.org/author/37668186700](https://ieeexplore.ieee.org/author/37668186700)
# 4. [https://app.dimensions.ai/discover/publication?and_facet_researcher=ur.010005224621.17](https://app.dimensions.ai/discover/publication?and_facet_researcher=ur.010005224621.17)

# %% [markdown]
# $\textbf{Preprocesamiento de los datos}$

# %% [markdown]
# Importamos los datos de la UAM y eliminamos la columna de "importantes" ya que no es necesaria para el análisis.

# %%
datos = pd.read_csv("uam-personal-pdi-2020-anonimizado.csv")
datos = datos.drop(columns=["IMPORTANTE"])
datos
# Out:
#       cod_universidad                 des_universidad  anio  \
# 0                  23  Universidad Autónoma de Madrid  2020
# 1                  23  Universidad Autónoma de Madrid  2020
# 2                  23  Universidad Autónoma de Madrid  2020
# 3                  23  Universidad Autónoma de Madrid  2020
# 4                  23  Universidad Autónoma de Madrid  2020
# ...               ...                             ...   ...
# 2598               23  Universidad Autónoma de Madrid  2020
# 2599               23  Universidad Autónoma de Madrid  2020
# 2600               23  Universidad Autónoma de Madrid  2020
# 2601               23  Universidad Autónoma de Madrid  2020
# 2602               23  Universidad Autónoma de Madrid  2020
#
#       cod_pais_nacionalidad des_pais_nacionalidad  lat_pais_nacionalidad  \
# 0                       724                España              40.463667
# 1                       724                España              40.463667
# 2                       724                España              40.463667
# 3                       724                España              40.463667
# 4                       724                España              40.463667
# ...                     ...                   ...                    ...
# 2598                    724                España              40.463667
# 2599                    724                España              40.463667
# 2600                    724                España              40.463667
# 2601                    724                España              40.463667
# 2602                    724                España              40.463667
#
#       lon_pais_nacionalidad  cod_continente_nacionalidad  \
# 0                  -3.74922                          150
# 1                  -3.74922                          150
# 2                  -3.74922                          150
# 3                  -3.74922                          150
# 4                  -3.74922                          150
# ...                     ...                          ...
# 2598               -3.74922                          150
# 2599               -3.74922                          150
# 2600               -3.74922                          150
# 2601               -3.74922                          150
# 2602               -3.74922                          150
#
#      des_continente_nacionalidad  cod_agregacion_paises_nacionalidad  ...  \
# 0                         Europa                                  39  ...
# 1                         Europa                                  39  ...
# 2                         Europa                                  39  ...
# 3                         Europa                                  39  ...
# 4                         Europa                                  39  ...
# ...                          ...                                 ...  ...
# 2598                      Europa                                  39  ...
# 2599                      Europa                                  39  ...
# 2600                      Europa                                  39  ...
# 2601                      Europa                                  39  ...
# 2602                      Europa                                  39  ...
#
#                                  des_unidad_responsable  \
# 0     Departamento de Educación Física, Deporte y Mo...
# 1     Departamento de Educación Física, Deporte y Mo...
# 2     Departamento de Educación Física, Deporte y Mo...
# 3     Departamento de Educación Física, Deporte y Mo...
# 4     Departamento de Educación Física, Deporte y Mo...
# ...                                                 ...
# 2598                                                NaN
# 2599                                                NaN
# 2600                                                NaN
# 2601                                                NaN
# 2602                                                NaN
#
#       cod_area_conocimiento               des_area_conocimiento  \
# 0                     187.0  Didáctica de la Expresión Corporal
# 1                     187.0  Didáctica de la Expresión Corporal
# 2                     187.0  Didáctica de la Expresión Corporal
# 3                     187.0  Didáctica de la Expresión Corporal
# 4                     187.0  Didáctica de la Expresión Corporal
# ...                     ...                                 ...
# 2598                    NaN                                 NaN
# 2599                    NaN                                 NaN
# 2600                    NaN                                 NaN
# 2601                    NaN                                 NaN
# 2602                    NaN                                 NaN
#
#       anio_incorporacion_ap anio_incorpora_cuerpo_docente  num_trienios  \
# 0                       NaN                           NaN             7
# 1                    1996.0                        2003.0             7
# 2                       NaN                           NaN             5
# 3                       NaN                           NaN            11
# 4                       NaN                           NaN             0
# ...                     ...                           ...           ...
# 2598                 1977.0                        1986.0            14
# 2599                 1971.0                        1985.0            12
# 2600                 1987.0                        2000.0             6
# 2601                    NaN                           NaN             0
# 2602                    NaN                           NaN             6
#
#      num_quinquenios  num_sexenios  num_tesis ind_investigador_principal
# 0                  4             1        NaN                          S
# 1                  4             2        NaN                          N
# 2                  3             0        NaN                          N
# 3                  5             0        NaN                          N
# 4                  0             0        1.0                          N
# ...              ...           ...        ...                        ...
# 2598               6             6        NaN                          S
# 2599               0             0        NaN                          N
# 2600               3             2        NaN                          N
# 2601               0             0        NaN                          N
# 2602               2             2        NaN                          N
#
# [2603 rows x 63 columns]

# %% [markdown]
# Debido a la información aportada en el proceso de anonimización por la UAM, sabemos que la variables pivote son des_unidad_responsable y des_genero, y conocemos los valores de Ortigosa para ambos campos, esto es:
#
# - Departamento de Ingeniería Informática
#
# - Hombre

# %%
datos_ortigosa = datos.loc[(datos['des_unidad_responsable'] == 'Departamento de Ingeniería Informática') & (datos['des_genero']=='Hombre')]
datos_ortigosa
# Out:
#      cod_universidad                 des_universidad  anio  \
# 200               23  Universidad Autónoma de Madrid  2020
# 201               23  Universidad Autónoma de Madrid  2020
# 202               23  Universidad Autónoma de Madrid  2020
# 203               23  Universidad Autónoma de Madrid  2020
# 204               23  Universidad Autónoma de Madrid  2020
# 205               23  Universidad Autónoma de Madrid  2020
# 206               23  Universidad Autónoma de Madrid  2020
# 207               23  Universidad Autónoma de Madrid  2020
# 208               23  Universidad Autónoma de Madrid  2020
# 209               23  Universidad Autónoma de Madrid  2020
# 210               23  Universidad Autónoma de Madrid  2020
# 211               23  Universidad Autónoma de Madrid  2020
# 212               23  Universidad Autónoma de Madrid  2020
# 213               23  Universidad Autónoma de Madrid  2020
# 214               23  Universidad Autónoma de Madrid  2020
# 215               23  Universidad Autónoma de Madrid  2020
# 216               23  Universidad Autónoma de Madrid  2020
# 217               23  Universidad Autónoma de Madrid  2020
# 218               23  Universidad Autónoma de Madrid  2020
# 219               23  Universidad Autónoma de Madrid  2020
# 220               23  Universidad Autónoma de Madrid  2020
# 221               23  Universidad Autónoma de Madrid  2020
# 222               23  Universidad Autónoma de Madrid  2020
# 223               23  Universidad Autónoma de Madrid  2020
# 224               23  Universidad Autónoma de Madrid  2020
# 225               23  Universidad Autónoma de Madrid  2020
# 226               23  Universidad Autónoma de Madrid  2020
# 227               23  Universidad Autónoma de Madrid  2020
# 228               23  Universidad Autónoma de Madrid  2020
# 229               23  Universidad Autónoma de Madrid  2020
# 230               23  Universidad Autónoma de Madrid  2020
# 231               23  Universidad Autónoma de Madrid  2020
# 232               23  Universidad Autónoma de Madrid  2020
# 233               23  Universidad Autónoma de Madrid  2020
# 234               23  Universidad Autónoma de Madrid  2020
# 235               23  Universidad Autónoma de Madrid  2020
# 236               23  Universidad Autónoma de Madrid  2020
# 237               23  Universidad Autónoma de Madrid  2020
# 238               23  Universidad Autónoma de Madrid  2020
# 239               23  Universidad Autónoma de Madrid  2020
# 240               23  Universidad Autónoma de Madrid  2020
# 241               23  Universidad Autónoma de Madrid  2020
# 242               23  Universidad Autónoma de Madrid  2020
# 243               23  Universidad Autónoma de Madrid  2020
# 244               23  Universidad Autónoma de Madrid  2020
# 245               23  Universidad Autónoma de Madrid  2020
# 246               23  Universidad Autónoma de Madrid  2020
# 247               23  Universidad Autónoma de Madrid  2020
# 248               23  Universidad Autónoma de Madrid  2020
# 249               23  Universidad Autónoma de Madrid  2020
# 250               23  Universidad Autónoma de Madrid  2020
# 251               23  Universidad Autónoma de Madrid  2020
# 252               23  Universidad Autónoma de Madrid  2020
# 253               23  Universidad Autónoma de Madrid  2020
#
#      cod_pais_nacionalidad des_pais_nacionalidad  lat_pais_nacionalidad  \
# 200                    724                España              40.463667
# 201                    724                España              40.463667
# 202                    724                España              40.463667
# 203                    724                España              40.463667
# 204                    724                España              40.463667
# 205                    724                España              40.463667
# 206                    724                España              40.463667
# 207                    380                Italia              41.871940
# 208                    724                España              40.463667
# 209                    724                España              40.463667
# 210                    724                España              40.463667
# 211                    724                España              40.463667
# 212                    724                España              40.463667
# 213                    724                España              40.463667
# 214                    724                España              40.463667
# 215                    724                España              40.463667
# 216                    380                Italia              41.871940
# 217                    724                España              40.463667
# 218                    724                España              40.463667
# 219                    724                España              40.463667
# 220                    724                España              40.463667
# 221                    724                España              40.463667
# 222                    724                España              40.463667
# 223                    724                España              40.463667
# 224                    724                España              40.463667
# 225                    724                España              40.463667
# 226                    724                España              40.463667
# 227                    724                España              40.463667
# 228                    724                España              40.463667
# 229                    724                España              40.463667
# 230                    724                España              40.463667
# 231                    724                España              40.463667
# 232                    724                España              40.463667
# 233                    724                España              40.463667
# 234                    724                España              40.463667
# 235                    724                España              40.463667
# 236                    724                España              40.463667
# 237                    724                España              40.463667
# 238                    724                España              40.463667
# 239                    724                España              40.463667
# 240                    724                España              40.463667
# 241                    724                España              40.463667
# 242                    724                España              40.463667
# 243                    724                España              40.463667
# 244                    724                España              40.463667
# 245                    724                España              40.463667
# 246                    724                España              40.463667
# 247                    724                España              40.463667
# 248                    724                España              40.463667
# 249                    724                España              40.463667
# 250                    724                España              40.463667
# 251                    724                España              40.463667
# 252                    724                España              40.463667
# 253                    724                España              40.463667
#
#      lon_pais_nacionalidad  cod_continente_nacionalidad  \
# 200               -3.74922                          150
# 201               -3.74922                          150
# 202               -3.74922                          150
# 203               -3.74922                          150
# 204               -3.74922                          150
# 205               -3.74922                          150
# 206               -3.74922                          150
# 207               12.56738                          150
# 208               -3.74922                          150
# 209               -3.74922                          150
# 210               -3.74922                          150
# 211               -3.74922                          150
# 212               -3.74922                          150
# 213               -3.74922                          150
# 214               -3.74922                          150
# 215               -3.74922                          150
# 216               12.56738                          150
# 217               -3.74922                          150
# 218               -3.74922                          150
# 219               -3.74922                          150
# 220               -3.74922                          150
# 221               -3.74922                          150
# 222               -3.74922                          150
# 223               -3.74922                          150
# 224               -3.74922                          150
# 225               -3.74922                          150
# 226               -3.74922                          150
# 227               -3.74922                          150
# 228               -3.74922                          150
# 229               -3.74922                          150
# 230               -3.74922                          150
# 231               -3.74922                          150
# 232               -3.74922                          150
# 233               -3.74922                          150
# 234               -3.74922                          150
# 235               -3.74922                          150
# 236               -3.74922                          150
# 237               -3.74922                          150
# 238               -3.74922                          150
# 239               -3.74922                          150
# 240               -3.74922                          150
# 241               -3.74922                          150
# 242               -3.74922                          150
# 243               -3.74922                          150
# 244               -3.74922                          150
# 245               -3.74922                          150
# 246               -3.74922                          150
# 247               -3.74922                          150
# 248               -3.74922                          150
# 249               -3.74922                          150
# 250               -3.74922                          150
# 251               -3.74922                          150
# 252               -3.74922                          150
# 253               -3.74922                          150
#
#     des_continente_nacionalidad  cod_agregacion_paises_nacionalidad  ...  \
# 200                      Europa                                  39  ...
# 201                      Europa                                  39  ...
# 202                      Europa                                  39  ...
# 203                      Europa                                  39  ...
# 204                      Europa                                  39  ...
# 205                      Europa                                  39  ...
# 206                      Europa                                  39  ...
# 207                      Europa                                  39  ...
# 208                      Europa                                  39  ...
# 209                      Europa                                  39  ...
# 210                      Europa                                  39  ...
# 211                      Europa                                  39  ...
# 212                      Europa                                  39  ...
# 213                      Europa                                  39  ...
# 214                      Europa                                  39  ...
# 215                      Europa                                  39  ...
# 216                      Europa                                  39  ...
# 217                      Europa                                  39  ...
# 218                      Europa                                  39  ...
# 219                      Europa                                  39  ...
# 220                      Europa                                  39  ...
# 221                      Europa                                  39  ...
# 222                      Europa                                  39  ...
# 223                      Europa                                  39  ...
# 224                      Europa                                  39  ...
# 225                      Europa                                  39  ...
# 226                      Europa                                  39  ...
# 227                      Europa                                  39  ...
# 228                      Europa                                  39  ...
# 229                      Europa                                  39  ...
# 230                      Europa                                  39  ...
# 231                      Europa                                  39  ...
# 232                      Europa                                  39  ...
# 233                      Europa                                  39  ...
# 234                      Europa                                  39  ...
# 235                      Europa                                  39  ...
# 236                      Europa                                  39  ...
# 237                      Europa                                  39  ...
# 238                      Europa                                  39  ...
# 239                      Europa                                  39  ...
# 240                      Europa                                  39  ...
# 241                      Europa                                  39  ...
# 242                      Europa                                  39  ...
# 243                      Europa                                  39  ...
# 244                      Europa                                  39  ...
# 245                      Europa                                  39  ...
# 246                      Europa                                  39  ...
# 247                      Europa                                  39  ...
# 248                      Europa                                  39  ...
# 249                      Europa                                  39  ...
# 250                      Europa                                  39  ...
# 251                      Europa                                  39  ...
# 252                      Europa                                  39  ...
# 253                      Europa                                  39  ...
#
#                      des_unidad_responsable  cod_area_conocimiento  \
# 200  Departamento de Ingeniería Informática                   75.0
# 201  Departamento de Ingeniería Informática                   75.0
# 202  Departamento de Ingeniería Informática                   75.0
# 203  Departamento de Ingeniería Informática                   75.0
# 204  Departamento de Ingeniería Informática                   75.0
# 205  Departamento de Ingeniería Informática                  570.0
# 206  Departamento de Ingeniería Informática                   75.0
# 207  Departamento de Ingeniería Informática                  570.0
# 208  Departamento de Ingeniería Informática                   75.0
# 209  Departamento de Ingeniería Informática                  570.0
# 210  Departamento de Ingeniería Informática                   75.0
# 211  Departamento de Ingeniería Informática                  570.0
# 212  Departamento de Ingeniería Informática                   75.0
# 213  Departamento de Ingeniería Informática                  570.0
# 214  Departamento de Ingeniería Informática                  570.0
# 215  Departamento de Ingeniería Informática                   75.0
# 216  Departamento de Ingeniería Informática                   75.0
# 217  Departamento de Ingeniería Informática                  570.0
# 218  Departamento de Ingeniería Informática                   75.0
# 219  Departamento de Ingeniería Informática                   75.0
# 220  Departamento de Ingeniería Informática                  570.0
# 221  Departamento de Ingeniería Informática                   75.0
# 222  Departamento de Ingeniería Informática                  570.0
# 223  Departamento de Ingeniería Informática                  570.0
# 224  Departamento de Ingeniería Informática                   75.0
# 225  Departamento de Ingeniería Informática                   75.0
# 226  Departamento de Ingeniería Informática                  570.0
# 227  Departamento de Ingeniería Informática                   75.0
# 228  Departamento de Ingeniería Informática                  570.0
# 229  Departamento de Ingeniería Informática                  570.0
# 230  Departamento de Ingeniería Informática                  570.0
# 231  Departamento de Ingeniería Informática                   75.0
# 232  Departamento de Ingeniería Informática                   75.0
# 233  Departamento de Ingeniería Informática                  570.0
# 234  Departamento de Ingeniería Informática                   75.0
# 235  Departamento de Ingeniería Informática                  570.0
# 236  Departamento de Ingeniería Informática                   75.0
# 237  Departamento de Ingeniería Informática                   75.0
# 238  Departamento de Ingeniería Informática                   75.0
# 239  Departamento de Ingeniería Informática                   75.0
# 240  Departamento de Ingeniería Informática                  570.0
# 241  Departamento de Ingeniería Informática                  570.0
# 242  Departamento de Ingeniería Informática                   75.0
# 243  Departamento de Ingeniería Informática                   75.0
# 244  Departamento de Ingeniería Informática                  570.0
# 245  Departamento de Ingeniería Informática                   75.0
# 246  Departamento de Ingeniería Informática                   75.0
# 247  Departamento de Ingeniería Informática                   75.0
# 248  Departamento de Ingeniería Informática                  570.0
# 249  Departamento de Ingeniería Informática                  570.0
# 250  Departamento de Ingeniería Informática                   75.0
# 251  Departamento de Ingeniería Informática                  570.0
# 252  Departamento de Ingeniería Informática                   75.0
# 253  Departamento de Ingeniería Informática                   75.0
#
#                                  des_area_conocimiento  anio_incorporacion_ap  \
# 200  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 201  Ciencia de la Computación e Inteligencia Artif...                 1995.0
# 202  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 203  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 204  Ciencia de la Computación e Inteligencia Artif...                 1998.0
# 205                  Lenguajes y Sistemas Informáticos                    NaN
# 206  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 207                  Lenguajes y Sistemas Informáticos                    NaN
# 208  Ciencia de la Computación e Inteligencia Artif...                 1997.0
# 209                  Lenguajes y Sistemas Informáticos                 2005.0
# 210  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 211                  Lenguajes y Sistemas Informáticos                    NaN
# 212  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 213                  Lenguajes y Sistemas Informáticos                    NaN
# 214                  Lenguajes y Sistemas Informáticos                 1996.0
# 215  Ciencia de la Computación e Inteligencia Artif...                 1990.0
# 216  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 217                  Lenguajes y Sistemas Informáticos                    NaN
# 218  Ciencia de la Computación e Inteligencia Artif...                 1997.0
# 219  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 220                  Lenguajes y Sistemas Informáticos                 1995.0
# 221  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 222                  Lenguajes y Sistemas Informáticos                    NaN
# 223                  Lenguajes y Sistemas Informáticos                 1993.0
# 224  Ciencia de la Computación e Inteligencia Artif...                 1996.0
# 225  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 226                  Lenguajes y Sistemas Informáticos                 1982.0
# 227  Ciencia de la Computación e Inteligencia Artif...                 1995.0
# 228                  Lenguajes y Sistemas Informáticos                 1977.0
# 229                  Lenguajes y Sistemas Informáticos                    NaN
# 230                  Lenguajes y Sistemas Informáticos                    NaN
# 231  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 232  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 233                  Lenguajes y Sistemas Informáticos                 1998.0
# 234  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 235                  Lenguajes y Sistemas Informáticos                    NaN
# 236  Ciencia de la Computación e Inteligencia Artif...                 1994.0
# 237  Ciencia de la Computación e Inteligencia Artif...                 1999.0
# 238  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 239  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 240                  Lenguajes y Sistemas Informáticos                    NaN
# 241                  Lenguajes y Sistemas Informáticos                    NaN
# 242  Ciencia de la Computación e Inteligencia Artif...                 1993.0
# 243  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 244                  Lenguajes y Sistemas Informáticos                 1997.0
# 245  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 246  Ciencia de la Computación e Inteligencia Artif...                 1989.0
# 247  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 248                  Lenguajes y Sistemas Informáticos                    NaN
# 249                  Lenguajes y Sistemas Informáticos                    NaN
# 250  Ciencia de la Computación e Inteligencia Artif...                    NaN
# 251                  Lenguajes y Sistemas Informáticos                    NaN
# 252  Ciencia de la Computación e Inteligencia Artif...                 2001.0
# 253  Ciencia de la Computación e Inteligencia Artif...                    NaN
#
#     anio_incorpora_cuerpo_docente  num_trienios num_quinquenios  num_sexenios  \
# 200                           NaN             1               0             0
# 201                        1999.0             8               4             2
# 202                           NaN             6               3             4
# 203                           NaN             7               0             0
# 204                        2012.0             7               4             3
# 205                           NaN             3               1             1
# 206                           NaN             0               0             0
# 207                           NaN             1               0             0
# 208                        2006.0             7               2             4
# 209                        2019.0             5               1             4
# 210                           NaN             0               0             0
# 211                           NaN             6               3             2
# 212                           NaN             0               0             0
# 213                           NaN             6               3             2
# 214                        2006.0             7               3             3
# 215                        1999.0            10               6             0
# 216                           NaN             4               0             0
# 217                           NaN             2               0             0
# 218                        2001.0             7               6             5
# 219                           NaN             7               2             2
# 220                        2002.0             8               5             5
# 221                           NaN             1               0             0
# 222                           NaN             5               0             0
# 223                        1997.0             9               5             4
# 224                        2020.0             7               3             4
# 225                           NaN             0               0             0
# 226                        1985.0            12               6             6
# 227                        2001.0             8               5             2
# 228                        1986.0            14               6             4
# 229                           NaN             6               2             3
# 230                           NaN             5               2             2
# 231                           NaN             4               2             3
# 232                           NaN             1               0             0
# 233                        2011.0             7               3             3
# 234                           NaN             4               1             1
# 235                           NaN             1               0             0
# 236                        1997.0             8               6             2
# 237                        2005.0             7               4             3
# 238                           NaN             0               0             0
# 239                           NaN             7               4             3
# 240                           NaN             0               0             0
# 241                           NaN             6               3             0
# 242                        1998.0             9               5             5
# 243                           NaN             3               2             2
# 244                        2002.0             7               5             4
# 245                           NaN             6               4             3
# 246                        2001.0             8               5             2
# 247                           NaN             2               0             0
# 248                           NaN             8               0             0
# 249                           NaN             5               0             0
# 250                           NaN             8               4             2
# 251                           NaN             0               0             0
# 252                        2020.0             6               3             4
# 253                           NaN             6               3             0
#
#      num_tesis ind_investigador_principal
# 200        NaN                          N
# 201        NaN                          N
# 202        NaN                          N
# 203        NaN                          N
# 204        NaN                          N
# 205        NaN                          N
# 206        NaN                          N
# 207        NaN                          N
# 208        NaN                          N
# 209        NaN                          N
# 210        NaN                          N
# 211        1.0                          N
# 212        NaN                          N
# 213        NaN                          N
# 214        NaN                          N
# 215        NaN                          N
# 216        NaN                          N
# 217        NaN                          S
# 218        NaN                          S
# 219        NaN                          S
# 220        NaN                          N
# 221        NaN                          N
# 222        NaN                          S
# 223        NaN                          S
# 224        NaN                          N
# 225        NaN                          N
# 226        NaN                          N
# 227        NaN                          N
# 228        NaN                          S
# 229        NaN                          N
# 230        NaN                          N
# 231        NaN                          N
# 232        NaN                          N
# 233        NaN                          N
# 234        NaN                          N
# 235        NaN                          N
# 236        NaN                          N
# 237        NaN                          N
# 238        NaN                          S
# 239        NaN                          S
# 240        NaN                          N
# 241        NaN                          N
# 242        NaN                          N
# 243        NaN                          N
# 244        1.0                          S
# 245        NaN                          S
# 246        NaN                          N
# 247        NaN                          N
# 248        NaN                          S
# 249        NaN                          N
# 250        NaN                          S
# 251        NaN                          S
# 252        NaN                          S
# 253        NaN                          S
#
# [54 rows x 63 columns]

# %% [markdown]
# A continuación, se inferirá el valor más probable de cada campo utilizando información del propio dataset (sacando las distintas frecuencias relativas) y utilizando distintas fuentes externas. Dado que las permutaciones en el proceso de anonimización se mantienen para cada bloque, la confianza de inferir el valor más probable dependerá del resto de campos que pertenezcan al mismo bloque.

# %%
bloques = {1:['des_universidad','anio'],
           2:['des_pais_nacionalidad','des_continente_nacionalidad', 'des_agregacion_paises_nacionalidad'],
           3:['des_comunidad_residencia','des_provincia_residencia', 'des_municipio_residencia'],
           4:['anio_nacimiento'],
           5:['des_tipo_personal', 'des_categoria_cuerpo_escala', 'des_tipo_contrato', 'des_dedicacion', 'num_horas_semanales_tiempo_parcial', 'des_situacion_administrativa'],
           6:['ind_cargo_remunerado'],
           7:['des_titulo_doctorado', 'des_pais_doctorado', 'des_continente_doctorado', 'des_agregacion_paises_doctorado', 'des_universidad_doctorado', 'anio_lectura_tesis', 'anio_expedicion_titulo_doctor', 'des_mencion_europea'],
           8:['des_tipo_unidad_responsable', 'des_area_conocimiento'],
           9:['anio_incorporacion_ap', 'anio_incorpora_cuerpo_docente', 'num_trienios', 'num_quinquenios', 'num_sexenios'],
          10:['num_tesis'],
          11:['ind_investigador_principal']}

# %% [markdown]
# $\textbf{Bloque 1}$

# %%
bloque_1 = datos_ortigosa[bloques[1]]
bloque_1.head()
# Out:
#                     des_universidad  anio
# 200  Universidad Autónoma de Madrid  2020
# 201  Universidad Autónoma de Madrid  2020
# 202  Universidad Autónoma de Madrid  2020
# 203  Universidad Autónoma de Madrid  2020
# 204  Universidad Autónoma de Madrid  2020

# %%
bloque_1.value_counts(normalize=True, dropna=False)
# Out:
# des_universidad                 anio
# Universidad Autónoma de Madrid  2020    1.0
# dtype: float64

# %% [markdown]
# En la celda anterior se calculan las probabilidades de obtener cada par de valores (probabilidad conjunta) de los campos que pertenecen al primer bloque. De esta manera, los campos más probables para este bloque serán lo que maximicen la probabilidad conjunta.
#
# Como esperábamos por las condiciones dadas, solo existe una posibilidad para la que se obtiene una probabilidad del 100%. Por tanto, inferimos con una confianza del 100% que el profesor Ortigosa era docente en la Universidad Autónoma de Madrid en el año 2020.

# %% [markdown]
# $\textbf{Bloque 2}$

# %%
bloque_2 = datos_ortigosa[bloques[2]]
bloque_2.head()
# Out:
#     des_pais_nacionalidad des_continente_nacionalidad  \
# 200                España                      Europa
# 201                España                      Europa
# 202                España                      Europa
# 203                España                      Europa
# 204                España                      Europa
#
#     des_agregacion_paises_nacionalidad
# 200                  Europa meridional
# 201                  Europa meridional
# 202                  Europa meridional
# 203                  Europa meridional
# 204                  Europa meridional

# %%
bloque_2.value_counts(normalize=True, dropna=False)
# Out:
# des_pais_nacionalidad  des_continente_nacionalidad  des_agregacion_paises_nacionalidad
# España                 Europa                       Europa meridional                     0.962963
# Italia                 Europa                       Europa meridional                     0.037037
# dtype: float64

# %% [markdown]
# A la vista de los resultados obtenidos, obtenemos con una confianza del 100%, que Álvaro Ortigosa tiene una nacionalidad Europea de la Europa meridional. Respecto al país particular, las dos únicas posibilidades son que tenga nacionalidad Española o Italiana. Dado que lo más probable es que tenga nacionalidad española, concluimos con una confianza del 96.30% que tiene nacionalidad española. Además, en su perfil de Linkedin no aparece ninguna relación con Italia.

# %% [markdown]
# $\textbf{Bloque 3}$

# %%
bloque_3 = datos_ortigosa[bloques[3]]
bloque_3.head()
# Out:
#     des_comunidad_residencia des_provincia_residencia des_municipio_residencia
# 200                   Madrid                   Madrid                   MADRID
# 201                   Madrid                   Madrid                   MADRID
# 202                   Madrid                   Madrid       POZUELO DE ALARCÓN
# 203                   Madrid                   Madrid               ALCOBENDAS
# 204                   Madrid                   Madrid               ALCOBENDAS

# %%
bloque_3.value_counts(normalize=True, dropna=False)
# Out:
# des_comunidad_residencia  des_provincia_residencia  des_municipio_residencia
# Madrid                    Madrid                    MADRID                        0.500000
#                                                     COLMENAR VIEJO                0.111111
#                                                     ALCOBENDAS                    0.074074
#                                                     SAN SEBASTIÁN DE LOS REYES    0.074074
#                                                     TRES CANTOS                   0.055556
#                                                     ALCALÁ DE HENARES             0.018519
#                                                     ALCORCÓN                      0.018519
#                                                     ALGETE                        0.018519
#                                                     BOALO, EL                     0.018519
#                                                     COLMENAREJO                   0.018519
#                                                     FUENLABRADA                   0.018519
#                                                     GALAPAGAR                     0.018519
#                                                     HOYO DE MANZANARES            0.018519
#                                                     MORALZARZAL                   0.018519
#                                                     POZUELO DE ALARCÓN            0.018519
# dtype: float64

# %% [markdown]
# Inferimos con una probabilidad del 100% que Ortigosa reside en la Comunidad de Madrid. Respecto al municipio, con una confianza del 50.0% podríamos concluir que Ortigosa pertenece a Madrid o con una confianza del 50.0% que reside en uno de estos municipios (COLMENAR VIEJO, ALCOBENDAS, SAN SEBASTIÁN DE LOS REYES...).

# %% [markdown]
# $\textbf{Bloque 4}$

# %%
bloque_4 = datos_ortigosa[bloques[4]]
bloque_4.head()
# Out:
#      anio_nacimiento
# 200             1988
# 201             1980
# 202             1964
# 203             1978
# 204             1985

# %%
bloque_4.value_counts(normalize=True, dropna=False)
# Out:
# anio_nacimiento
# 1967               0.074074
# 1965               0.074074
# 1976               0.055556
# 1982               0.055556
# 1964               0.055556
# 1978               0.055556
# 1968               0.037037
# 1975               0.037037
# 1974               0.037037
# 1984               0.037037
# 1969               0.037037
# 1990               0.037037
# 1966               0.037037
# 1963               0.037037
# 1962               0.037037
# 1977               0.037037
# 1981               0.018519
# 1980               0.018519
# 1985               0.018519
# 1986               0.018519
# 1988               0.018519
# 1950               0.018519
# 1973               0.018519
# 1955               0.018519
# 1971               0.018519
# 1970               0.018519
# 1961               0.018519
# 1960               0.018519
# 1958               0.018519
# 1972               0.018519
# dtype: float64

# %% [markdown]
# A la vista de los resultados de este bloque, no podriamos sacar algo concluyente. Pero debido a su biografía, sabemos que nacio en el año 1968

# %% [markdown]
# $\textbf{Bloque 5}$

# %% [markdown]
# En Linkedin, y en el portal científico de la Autónoma Ortigosa figuraba como profesor asociado en 2019.

# %%
bloque_5 = datos_ortigosa[bloques[5]].loc[datos_ortigosa.des_categoria_cuerpo_escala == 'Profesor Asociado']
bloque_5.head()
# Out:
#     des_tipo_personal des_categoria_cuerpo_escala  \
# 204  Personal laboral           Profesor Asociado
# 208  Personal laboral           Profesor Asociado
# 211  Personal laboral           Profesor Asociado
# 215  Personal laboral           Profesor Asociado
# 217  Personal laboral           Profesor Asociado
#
#                     des_tipo_contrato               des_dedicacion  \
# 204  Contrato de Duración Determinada  Dedicación a Tiempo Parcial
# 208  Contrato de Duración Determinada  Dedicación a Tiempo Parcial
# 211  Contrato de Duración Determinada  Dedicación a Tiempo Parcial
# 215  Contrato de Duración Determinada  Dedicación a Tiempo Parcial
# 217  Contrato de Duración Determinada  Dedicación a Tiempo Parcial
#
#      num_horas_semanales_tiempo_parcial des_situacion_administrativa
# 204                                 8.0              Servicio Activo
# 208                                 8.0              Servicio Activo
# 211                                 8.0              Servicio Activo
# 215                                 8.0              Servicio Activo
# 217                                 8.0              Servicio Activo

# %%
bloque_5.value_counts(normalize=True, dropna=False)
# Out:
# des_tipo_personal  des_categoria_cuerpo_escala  des_tipo_contrato                 des_dedicacion               num_horas_semanales_tiempo_parcial  des_situacion_administrativa
# Personal laboral   Profesor Asociado            Contrato de Duración Determinada  Dedicación a Tiempo Parcial  8.0                                 Servicio Activo                 1.0
# dtype: float64

# %% [markdown]
# Con una probabilidad del 100% inferimos de los datos que Ortigosa en 2020 era personal laboral, profesor asociado, con un contrato de Duración Determinada y una dedicación a Tiempo Parcial de 8.0 horas semanales y un servicio activo.

# %% [markdown]
# $\textbf{Bloque 6}$

# %%
bloque_6 = datos_ortigosa[bloques[6]]
bloque_6.head()
# Out:
#     ind_cargo_remunerado
# 200                    N
# 201                    N
# 202                    S
# 203                    N
# 204                    S

# %%
bloque_6.value_counts(normalize=True, dropna=False)
# Out:
# ind_cargo_remunerado
# N                       0.833333
# S                       0.166667
# dtype: float64

# %% [markdown]
# Los datos nos aportan una mayor evidencia de que Álvaro Ortigosa no ocupa un cargo unipersonal. Pero en el portal científico de la Autónoma figuraba en 2020 como Director del INST. CIENCIAS FORENSES Y DE LA SEGURIDAD. Por tanto, concluimos que si ocupa un cargo unipersonal con una confianza del 100%.

# %%
bloque_6 = datos_ortigosa[bloques[6]].loc[datos_ortigosa.ind_cargo_remunerado == 'S']
bloque_6.head()
# Out:
#     ind_cargo_remunerado
# 202                    S
# 204                    S
# 208                    S
# 213                    S
# 231                    S

# %% [markdown]
# $\textbf{Bloque 7}$

# %% [markdown]
# Del portal científico de la autónoma, sabemos que realizó el Doctorado en España en la Universidad Autónoma de Madrid en Enero de 1997 y que lo terminó en Enero del 2000. Además, en la misma fuente indica que lo realizó en Ingeniería Informática y su tesis doctoral se titula: Método para la aplicación de documentación inteligente de frameworks orientados a objetos.

# %%
bloque_7 = datos_ortigosa[bloques[7]].loc[(datos_ortigosa.des_titulo_doctorado == "Uno") &
            (datos_ortigosa.anio_lectura_tesis == 2000) &
            (datos_ortigosa.des_universidad_doctorado == "Universidad Autónoma de Madrid")]
bloque_7.head()
# Out:
#     des_titulo_doctorado des_pais_doctorado des_continente_doctorado  \
# 213                  Uno             España                   Europa
# 229                  Uno             España                   Europa
#
#     des_agregacion_paises_doctorado       des_universidad_doctorado  \
# 213               Europa meridional  Universidad Autónoma de Madrid
# 229               Europa meridional  Universidad Autónoma de Madrid
#
#      anio_lectura_tesis  anio_expedicion_titulo_doctor des_mencion_europea
# 213              2000.0                         2000.0                  No
# 229              2000.0                         2000.0                  No

# %%
bloque_7.value_counts(normalize=True, dropna=False)
# Out:
# des_titulo_doctorado  des_pais_doctorado  des_continente_doctorado  des_agregacion_paises_doctorado  des_universidad_doctorado       anio_lectura_tesis  anio_expedicion_titulo_doctor  des_mencion_europea
# Uno                   España              Europa                    Europa meridional                Universidad Autónoma de Madrid  2000.0              2000.0                         No                     1.0
# dtype: float64

# %% [markdown]
# El resto de campos podemos inferirlos de los datos: Ortigosa expidió en título en el 2000 y no consiguió mención europea con una confianza del 100%.

# %% [markdown]
# $\textbf{Bloque 8}$

# %%
bloque_8 = datos_ortigosa[bloques[8]]
bloque_8.head()
# Out:
#     des_tipo_unidad_responsable  \
# 200                Departamento
# 201                Departamento
# 202                Departamento
# 203                Departamento
# 204                Departamento
#
#                                  des_area_conocimiento
# 200  Ciencia de la Computación e Inteligencia Artif...
# 201  Ciencia de la Computación e Inteligencia Artif...
# 202  Ciencia de la Computación e Inteligencia Artif...
# 203  Ciencia de la Computación e Inteligencia Artif...
# 204  Ciencia de la Computación e Inteligencia Artif...

# %%
bloque_8.value_counts(normalize=True, dropna=False)
# Out:
# des_tipo_unidad_responsable  des_area_conocimiento
# Departamento                 Ciencia de la Computación e Inteligencia Artificial    0.592593
#                              Lenguajes y Sistemas Informáticos                      0.407407
# dtype: float64

# %% [markdown]
# En el mismo sitio que en el bloque anterior, figura que su área de conocimiento es Lenguajes y Sistemas Informáticos. Sin embargo, no sabemos si en 2020 pertenecía a un área distinta. Los resultados son casi uniformes, así que no podemos concluir ninguna de las dos posibles opciones.

# %% [markdown]
# $\textbf{Bloque 9}$

# %% [markdown]
# También figura que Ortigosa tenía en 2016 un total de 3 quinquenios y que en 2017 tenía 4 sexenios.

# %%
bloque_9 = datos_ortigosa[bloques[9]].loc[(datos_ortigosa.num_sexenios == 4) &
            (datos_ortigosa.num_quinquenios == 3)]

# %%
bloque_9.value_counts(normalize=True, dropna=False)
# Out:
# anio_incorporacion_ap  anio_incorpora_cuerpo_docente  num_trienios  num_quinquenios  num_sexenios
# 1996.0                 2020.0                         7             3                4               0.333333
# 2001.0                 2020.0                         6             3                4               0.333333
# NaN                    NaN                            6             3                4               0.333333
# dtype: float64

# %% [markdown]
# No tenemos evidencia estadística del número de trienios ni del año de incorporación al cuerpo docente y a la administración pública, ya que todos lo posibles valores tienen una probabilidad uniforme.

# %% [markdown]
# $\textbf{Bloque 10}$

# %%
bloque_10 = datos_ortigosa[bloques[10]]
bloque_10.head()
# Out:
#      num_tesis
# 200        NaN
# 201        NaN
# 202        NaN
# 203        NaN
# 204        NaN

# %%
bloque_10.value_counts(normalize=True, dropna=False)
# Out:
# num_tesis
# NaN          0.962963
# 1.0          0.037037
# dtype: float64

# %% [markdown]
# De nuevo en el portal, aparece que Ortigosa ha dirigido 3 tesis pero no encontramos cuantas dirigió en 2020. Por tanto, suponiendo que Nan significa que no ha dirigido ninguna tesis, inferimos con una confianza del 96.30% que Álvaro Ortigosa no dirigió ninguna tesis en 2020.

# %% [markdown]
# $\textbf{Bloque 11}$

# %%
bloque_11 = datos_ortigosa[bloques[11]]
bloque_11.head()
# Out:
#     ind_investigador_principal
# 200                          N
# 201                          N
# 202                          N
# 203                          N
# 204                          N

# %%
bloque_11.value_counts(normalize=True, dropna=False)
# Out:
# ind_investigador_principal
# N                             0.722222
# S                             0.277778
# dtype: float64

# %% [markdown]
# Tanto los porcentajes, como la búsquedad realizada externamente (en el último enlace) nos das una ligera evidencia de que la respuesta a este bloque es que no.
